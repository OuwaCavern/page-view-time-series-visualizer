# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from pandas.plotting import register_matplotlib_converters

# %%
df = pd.read_csv("fcc-forum-pageviews.csv", parse_dates=["date"]).set_index("date")

# %%
df
# Out:
#              value
# date
# 2016-05-09    1201
# 2016-05-10    2329
# 2016-05-11    1716
# 2016-05-12   10539
# 2016-05-13    6933
# ...            ...
# 2019-11-29  171584
# 2019-11-30  141161
# 2019-12-01  142918
# 2019-12-02  220144
# 2019-12-03  158549
#
# [1304 rows x 1 columns]

# %%
df = df.drop(df[df["value"].quantile(0.025) > df["value"]].index)

# %%
df = df.drop(df[df["value"].quantile(0.975) < df["value"]].index)

# %%
df
# Out:
#              value
# date
# 2016-05-19   19736
# 2016-05-26   18060
# 2016-05-27   19997
# 2016-05-28   19044
# 2016-05-29   20325
# ...            ...
# 2019-11-24  138875
# 2019-11-29  171584
# 2019-11-30  141161
# 2019-12-01  142918
# 2019-12-03  158549
#
# [1239 rows x 1 columns]

# %%
fig, ax = plt.subplots(layout="constrained")

# %%
import matplotlib.dates as mdates

# %%
#None of these really work
#locator = mdates.AutoDateLocator()
#formatter = mdates.ConciseDateFormatter(locator)
#ax.xaxis.set_major_locator(locator)
#ax.xaxis.set_major_formatter(formatter)

# %%
from matplotlib.dates import (MONTHLY, DateFormatter, RRuleLocator, rrulewrapper)

# %%
#These don't work either
#rule = rrulewrapper(MONTHLY, bymonthday=1, interval=6, count=8)
#loc = RRuleLocator(rule)
#formatter = DateFormatter('%y-%m')

# %%
plt.figure(figsize = (20,5), dpi=100)
plt.xlabel("Date")
plt.ylabel("Page Views")
plt.plot(df, color="red")
plt.title("Daily freeCodeCamp Forum Page Views 5/2016-12/2019.")
# Out:
# Text(0.5, 1.0, 'Daily freeCodeCamp Forum Page Views 5/2016-12/2019.')

# %%
df_bar = df.copy()

# %%
df_bar
# Out:
#              value
# date
# 2016-05-19   19736
# 2016-05-26   18060
# 2016-05-27   19997
# 2016-05-28   19044
# 2016-05-29   20325
# ...            ...
# 2019-11-24  138875
# 2019-11-29  171584
# 2019-11-30  141161
# 2019-12-01  142918
# 2019-12-03  158549
#
# [1239 rows x 1 columns]

# %%
df_barbymonth = df_bar.resample("m").mean()

# %%
df_barbymonth.index.strftime("%Y-%b")
# Out:
# Index(['2016-May', '2016-Jun', '2016-Jul', '2016-Aug', '2016-Sep', '2016-Oct',
#        '2016-Nov', '2016-Dec', '2017-Jan', '2017-Feb', '2017-Mar', '2017-Apr',
#        '2017-May', '2017-Jun', '2017-Jul', '2017-Aug', '2017-Sep', '2017-Oct',
#        '2017-Nov', '2017-Dec', '2018-Jan', '2018-Feb', '2018-Mar', '2018-Apr',
#        '2018-May', '2018-Jun', '2018-Jul', '2018-Aug', '2018-Sep', '2018-Oct',
#        '2018-Nov', '2018-Dec', '2019-Jan', '2019-Feb', '2019-Mar', '2019-Apr',
#        '2019-May', '2019-Jun', '2019-Jul', '2019-Aug', '2019-Sep', '2019-Oct',
#        '2019-Nov', '2019-Dec'],
#       dtype='object', name='date')

# %%
months = ["January",  "February", "March","April", "May", "June", "July", "August", "September", "October", "November", "December"]
df_barbymonth['months'] = pd.Categorical(df_barbymonth.index.strftime('%B'), categories=months, ordered=True)

dfp = pd.pivot_table(data=df_barbymonth, index=pd.DatetimeIndex(data=df_barbymonth.index).strftime("%Y"), columns='months', values='value')

# %%
dfp
# Out:
# months        January       February         March         April  \
# date
# 2016              NaN            NaN           NaN           NaN
# 2017     32785.161290   31113.071429  29369.096774  30878.733333
# 2018     58580.096774   65679.000000  62693.774194  62350.833333
# 2019    102056.516129  105968.357143  91214.483871  89368.433333
#
# months           May          June          July         August     September  \
# date
# 2016    19432.400000  21875.105263  24109.678571   31049.193548  41476.866667
# 2017    34244.290323  43577.500000  65806.838710   47712.451613  47376.800000
# 2018    56562.870968  70117.000000  63591.064516   62831.612903  65941.733333
# 2019    91439.903226  90435.642857  97236.566667  102717.310345  97268.833333
#
# months        October       November       December
# date
# 2016     27398.322581   40448.633333   27832.419355
# 2017     47438.709677   57701.566667   48420.580645
# 2018    113663.275862   78688.333333   80047.483871
# 2019    122802.272727  143166.428571  150733.500000

# %%
ax = dfp.plot(kind='bar', figsize=(6, 5), ylabel='Mean Page Views', xlabel='Year', rot=0)
_ = ax.legend(bbox_to_anchor=(1, 1.02), loc="upper left")
plt.show()

# %%
dfformatted = pd.DatetimeIndex(data=df_barbymonth.index).strftime("%Y-%B")

# %%
df_clean = df_barbymonth.set_index(dfformatted)

# %%
df_clean
# Out:
#                         value     months
# date
# 2016-May         19432.400000        May
# 2016-June        21875.105263       June
# 2016-July        24109.678571       July
# 2016-August      31049.193548     August
# 2016-September   41476.866667  September
# 2016-October     27398.322581    October
# 2016-November    40448.633333   November
# 2016-December    27832.419355   December
# 2017-January     32785.161290    January
# 2017-February    31113.071429   February
# 2017-March       29369.096774      March
# 2017-April       30878.733333      April
# 2017-May         34244.290323        May
# 2017-June        43577.500000       June
# 2017-July        65806.838710       July
# 2017-August      47712.451613     August
# 2017-September   47376.800000  September
# 2017-October     47438.709677    October
# 2017-November    57701.566667   November
# 2017-December    48420.580645   December
# 2018-January     58580.096774    January
# 2018-February    65679.000000   February
# 2018-March       62693.774194      March
# 2018-April       62350.833333      April
# 2018-May         56562.870968        May
# 2018-June        70117.000000       June
# 2018-July        63591.064516       July
# 2018-August      62831.612903     August
# 2018-September   65941.733333  September
# 2018-October    113663.275862    October
# 2018-November    78688.333333   November
# 2018-December    80047.483871   December
# 2019-January    102056.516129    January
# 2019-February   105968.357143   February
# 2019-March       91214.483871      March
# 2019-April       89368.433333      April
# 2019-May         91439.903226        May
# 2019-June        90435.642857       June
# 2019-July        97236.566667       July
# 2019-August     102717.310345     August
# 2019-September   97268.833333  September
# 2019-October    122802.272727    October
# 2019-November   143166.428571   November
# 2019-December   150733.500000   December

# %%
dfh = pd.pivot_table(df_clean, values="value",index="date", aggfunc="sum")

# %%
dfh
# Out:
#                         value
# date
# 2016-August      31049.193548
# 2016-December    27832.419355
# 2016-July        24109.678571
# 2016-June        21875.105263
# 2016-May         19432.400000
# 2016-November    40448.633333
# 2016-October     27398.322581
# 2016-September   41476.866667
# 2017-April       30878.733333
# 2017-August      47712.451613
# 2017-December    48420.580645
# 2017-February    31113.071429
# 2017-January     32785.161290
# 2017-July        65806.838710
# 2017-June        43577.500000
# 2017-March       29369.096774
# 2017-May         34244.290323
# 2017-November    57701.566667
# 2017-October     47438.709677
# 2017-September   47376.800000
# 2018-April       62350.833333
# 2018-August      62831.612903
# 2018-December    80047.483871
# 2018-February    65679.000000
# 2018-January     58580.096774
# 2018-July        63591.064516
# 2018-June        70117.000000
# 2018-March       62693.774194
# 2018-May         56562.870968
# 2018-November    78688.333333
# 2018-October    113663.275862
# 2018-September   65941.733333
# 2019-April       89368.433333
# 2019-August     102717.310345
# 2019-December   150733.500000
# 2019-February   105968.357143
# 2019-January    102056.516129
# 2019-July        97236.566667
# 2019-June        90435.642857
# 2019-March       91214.483871
# 2019-May         91439.903226
# 2019-November   143166.428571
# 2019-October    122802.272727
# 2019-September   97268.833333

# %%
dfh.index = pd.to_datetime(dfh.index, format='%Y-%B')

# %%
dfh.index = dfh.index.strftime('%Y-%b')

# %%
dfh.index
# Out:
# Index(['2016-Aug', '2016-Dec', '2016-Jul', '2016-Jun', '2016-May', '2016-Nov',
#        '2016-Oct', '2016-Sep', '2017-Apr', '2017-Aug', '2017-Dec', '2017-Feb',
#        '2017-Jan', '2017-Jul', '2017-Jun', '2017-Mar', '2017-May', '2017-Nov',
#        '2017-Oct', '2017-Sep', '2018-Apr', '2018-Aug', '2018-Dec', '2018-Feb',
#        '2018-Jan', '2018-Jul', '2018-Jun', '2018-Mar', '2018-May', '2018-Nov',
#        '2018-Oct', '2018-Sep', '2019-Apr', '2019-Aug', '2019-Dec', '2019-Feb',
#        '2019-Jan', '2019-Jul', '2019-Jun', '2019-Mar', '2019-May', '2019-Nov',
#        '2019-Oct', '2019-Sep'],
#       dtype='object', name='date')

# %%
fig, ax = plt.subplots(layout="constrained")
plt.figure(figsize = (20,5), dpi=100)
plt.xlabel("Date")
plt.ylabel("Page Views")
plt.bar(x=[2016, 2017, 2018, 2019], height=99999,data=df_clean)
plt.title("Daily freeCodeCamp Forum Page Views 5/2016-12/2019.")
# Out:
# Text(0.5, 1.0, 'Daily freeCodeCamp Forum Page Views 5/2016-12/2019.')

# %%
df.index = df.index.strftime("%Y")

# %%
df.index
# Out:
# Index(['2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016',
#        '2016',
#        ...
#        '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019',
#        '2019'],
#       dtype='object', name='date', length=1239)

# %%
df_year = pd.pivot_table(data=df, values="value", index=df.index, aggfunc="sum")

# %%
df_year
# Out:
#          value
# date
# 2016   6320303
# 2017  15736295
# 2018  25361698
# 2019  30827814

# %%
ax = df_year.plot(kind='box', figsize=(6, 5), ylabel='Page Views', xlabel='Year')
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
plt.ticklabel_format(style="plain", axis="y")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_year.index, y='value', data=df_year)

plt.ticklabel_format(style='plain', axis="y")

plt.show()

# %%
df.index = pd.to_datetime(df.index)

# %%
df['year'] = df.index.year

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='year', y='value', data=df)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
dfh.in

# %%
dfh.index
# Out:
# DatetimeIndex(['2016-08-01', '2016-12-01', '2016-07-01', '2016-06-01',
#                '2016-05-01', '2016-11-01', '2016-10-01', '2016-09-01',
#                '2017-04-01', '2017-08-01', '2017-12-01', '2017-02-01',
#                '2017-01-01', '2017-07-01', '2017-06-01', '2017-03-01',
#                '2017-05-01', '2017-11-01', '2017-10-01', '2017-09-01',
#                '2018-04-01', '2018-08-01', '2018-12-01', '2018-02-01',
#                '2018-01-01', '2018-07-01', '2018-06-01', '2018-03-01',
#                '2018-05-01', '2018-11-01', '2018-10-01', '2018-09-01',
#                '2019-04-01', '2019-08-01', '2019-12-01', '2019-02-01',
#                '2019-01-01', '2019-07-01', '2019-06-01', '2019-03-01',
#                '2019-05-01', '2019-11-01', '2019-10-01', '2019-09-01'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
df_box = dfh.copy()
df_box.reset_index(inplace=True)
df_box['year'] = [d.year for d in df_box.date]
df_box['month'] = [d.month for d in df_box.date]

# %%
df_box
# Out:
#          date          value  year  month
# 0  2016-08-01   31049.193548  2016      8
# 1  2016-12-01   27832.419355  2016     12
# 2  2016-07-01   24109.678571  2016      7
# 3  2016-06-01   21875.105263  2016      6
# 4  2016-05-01   19432.400000  2016      5
# 5  2016-11-01   40448.633333  2016     11
# 6  2016-10-01   27398.322581  2016     10
# 7  2016-09-01   41476.866667  2016      9
# 8  2017-04-01   30878.733333  2017      4
# 9  2017-08-01   47712.451613  2017      8
# 10 2017-12-01   48420.580645  2017     12
# 11 2017-02-01   31113.071429  2017      2
# 12 2017-01-01   32785.161290  2017      1
# 13 2017-07-01   65806.838710  2017      7
# 14 2017-06-01   43577.500000  2017      6
# 15 2017-03-01   29369.096774  2017      3
# 16 2017-05-01   34244.290323  2017      5
# 17 2017-11-01   57701.566667  2017     11
# 18 2017-10-01   47438.709677  2017     10
# 19 2017-09-01   47376.800000  2017      9
# 20 2018-04-01   62350.833333  2018      4
# 21 2018-08-01   62831.612903  2018      8
# 22 2018-12-01   80047.483871  2018     12
# 23 2018-02-01   65679.000000  2018      2
# 24 2018-01-01   58580.096774  2018      1
# 25 2018-07-01   63591.064516  2018      7
# 26 2018-06-01   70117.000000  2018      6
# 27 2018-03-01   62693.774194  2018      3
# 28 2018-05-01   56562.870968  2018      5
# 29 2018-11-01   78688.333333  2018     11
# 30 2018-10-01  113663.275862  2018     10
# 31 2018-09-01   65941.733333  2018      9
# 32 2019-04-01   89368.433333  2019      4
# 33 2019-08-01  102717.310345  2019      8
# 34 2019-12-01  150733.500000  2019     12
# 35 2019-02-01  105968.357143  2019      2
# 36 2019-01-01  102056.516129  2019      1
# 37 2019-07-01   97236.566667  2019      7
# 38 2019-06-01   90435.642857  2019      6
# 39 2019-03-01   91214.483871  2019      3
# 40 2019-05-01   91439.903226  2019      5
# 41 2019-11-01  143166.428571  2019     11
# 42 2019-10-01  122802.272727  2019     10
# 43 2019-09-01   97268.833333  2019      9

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='year', y='value', data=df_box)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))
sns.boxplot(x='year', y='value', data=df_box, ax=axes[0])
axes[0].set_xlabel('Year')
axes[0].set_ylabel('Page Views')
axes[0].set_title('Year-wise Box Plot (Trend)')
month_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
sns.boxplot(x='month', y='value', data=df_box)
axes[1] = plt.xlabel('Month')
axes[1] = plt.xticks(ticks=plt.xticks()[0], labels=month_labels)
axes[1] = plt.ylabel('Page Views')
axes[1] = plt.title('Month-wise Box Plot (Seasonality)')

# %%
df_box
